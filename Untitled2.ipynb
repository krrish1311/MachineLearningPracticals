# %%
import pandas 
import numpy
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("Churn_Modelling.csv")

# %%
ds
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
ds.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
X = ds[[ 'CreditScore', 'Geography',
       'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary',]]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
ds.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Y =ds["Exited"]

# %%
geo=ds["Geography"]

# %%
geo=pd.get_dummies(geo ,drop_first=True)

# %%
geo
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gen=ds["Gender"]

# %%
gen=pd.get_dummies(gen ,drop_first=True)

# %%
gen
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
 x_final= pd.concat([gen,geo,X],axis=1)

# %%
x_final
# Out:
#       Male  Germany  Spain  CreditScore Geography  Gender  Age  Tenure  \
# 0        0        0      0          619    France  Female   42       2
# 1        0        0      1          608     Spain  Female   41       1
# 2        0        0      0          502    France  Female   42       8
# 3        0        0      0          699    France  Female   39       1
# 4        0        0      1          850     Spain  Female   43       2
# ...    ...      ...    ...          ...       ...     ...  ...     ...
# 9995     1        0      0          771    France    Male   39       5
# 9996     1        0      0          516    France    Male   35      10
# 9997     0        0      0          709    France  Female   36       7
# 9998     1        1      0          772   Germany    Male   42       3
# 9999     0        0      0          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y_final=ds["Exited"]

# %%
from sklearn.model_selection import train_test_split

# %%
# Now split data into training and testing 
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test=tts(x_final,y_final,test_size=0.2,random_state=96)

# %%
X_train.shape
# Out:
# (8000, 13)

# %%
X_test.shape
# Out:
# (2000, 13)

# %%
#splitting data into testing and training is done f

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(units=8 ,input_dim=11 ,activation="relu" ,kernel_initializer="zeros",bias_initializer="zeros"))

# %%
model.add(Dense(units=6 ,input_dim=8, activation="relu" ,kernel_initializer="zeros",bias_initializer="zeros"))

# %%
model.add(Dense(units=1 ,input_dim=8, activation="sigmoid"))

# %%
#After layeer creation compile the model  and for compilaton we need Adam 
#who will  provide this
# Out:
#   File "<ipython-input-29-a004253febd5>", line 2
#     who will  provide this
#         ^
# SyntaxError: invalid syntax

# %%
from keras.optimizers import Adam
model.compile(optimizer = Adam(learning_rate=0.00001), loss="Binary_Classentropy")

# %%
model.fit(X_train ,y_train ,epochs=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\data\util\structure.py in normalize_element(element, element_signature)
#     105         if spec is None:
# --> 106           spec = type_spec_from_value(t, use_fallback=False)
#     107       except TypeError:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\util\structure.py in type_spec_from_value(element, use_fallback)
#     478
# --> 479   raise TypeError("Could not build a TypeSpec for %r with type %s" %
#     480                   (element, type(element).__name__))
#
# TypeError: Could not build a TypeSpec for       Male  Germany  Spain  CreditScore Geography  Gender  Age  Tenure  \
# 6589     1        1      0          498   Germany    Male   45       7
# 8969     0        0      0          562    France  Female   51       7
# ...
